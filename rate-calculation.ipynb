# %%
import MDAnalysis as mda
import numpy as np
import MDAnalysis.core.groups
import MDAnalysis.analysis.distances as distances
import MDAnalysis.analysis.contacts as contacts
from MDAnalysis.analysis.rms import RMSD
from MDAnalysis.analysis.leaflet import LeafletFinder
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import csv

# %%
def import_columns_from_csv(csv_file, columns):
    # Initialize empty lists to store the columns
    imported_columns = [[] for _ in range(len(columns))]
    
    # Open the CSV file and read its contents
    with open(csv_file, 'r') as file:
        reader = csv.reader(file)
        
        # Iterate through each row in the CSV file
        for i, row in enumerate(reader):
            # Skip the first row
            if i == 0:
                continue
            
            # Iterate through each specified column
            for j, col in enumerate(columns):
                # Append the value in the specified column to the corresponding list
                imported_columns[j].append(float(row[col]))
    
    # Convert the lists to NumPy arrays
    arrays = [np.array(col) for col in imported_columns]
    
    return arrays



lf001='/media/favour/LaCie/july24/393K/bigger-box-393/fas_lipoicacid/flux/TRANS_TimeLine_s100.csv'
fas= '/media/favour/LaCie/july24/393K/bigger-box-393/fas/flux/TRANS_TimeLine_s100.csv'
nh3= '/media/favour/LaCie/july24/393K/bigger-box-393/nh3/flux/TRANS_TimeLine_s100.csv'
nic= '/media/favour/LaCie/july24/393K/bigger-box-393/nicotine/flux/TRANS_TimeLine_s100.csv'
cyt= '/media/favour/LaCie/july24/393K/bigger-box-393/tabex/flux/TRANS_TimeLine_s100.csv'
fas_440= '/media/favour/LaCie/july24/440K/fas-full/flux/TRANS_TimeLine_s100.csv'
nic_440= '/media/favour/LaCie/july24/440K/nic-full/flux/TRANS_TimeLine_s100.csv'
nh3_440= '/media/favour/LaCie/july24/440K/nh3-full/flux/TRANS_TimeLine_s100.csv'
nh3_310= '/media/favour/LaCie/july24/310K/nh3-full/flux/TRANS_TimeLine_s100.csv'
nic_310= '/media/favour/LaCie/july24/310K/nicotine-full/flux/TRANS_TimeLine_s100.csv'
#print(csv_file.columns)


columns_lf001 = [1, 2,16]
arrays_lf001 = import_columns_from_csv(lf001, columns_lf001)

columns_fas = [1, 2,16]  
arrays_fas = import_columns_from_csv(fas, columns_fas)

columns_nh3 = [1, 2,16]  
arrays_nh3 = import_columns_from_csv(nh3, columns_nh3)

columns_nic = [1, 2,16] 
arrays_nic = import_columns_from_csv(nic, columns_nic)

columns_cyt = [1, 2,16]  
arrays_cyt = import_columns_from_csv(cyt, columns_cyt)

columns_fas_440 = [1, 2,16]  
arrays_fas_440 = import_columns_from_csv(fas_440, columns_fas_440)

columns_nic_440 = [1, 2,16]  
arrays_nic_440 = import_columns_from_csv(nic_440, columns_nic_440)

columns_nh3_440 = [1, 2,16]  
arrays_nh3_440 = import_columns_from_csv(nh3_440, columns_nh3_440)

columns_nh3_310 = [1, 2,16]  
arrays_nh3_310 = import_columns_from_csv(nh3_310, columns_nh3_310)

columns_nic_310 = [1, 2,16]  
arrays_nic_310 = import_columns_from_csv(nic_310, columns_nic_310)
#print(arrays_lf001[0])  # time(ns)
#print(arrays_lf001[1])  # dt(ns) need to do average of this over 100 to get 1 ns
#print(arrays_lf001[2])  # number of crossings (sum)

# %%
def import_columns_from_csv(csv_file, columns):
    # Initialize empty lists to store the columns
    imported_columns = [[] for _ in range(len(columns))]
    
    # Open the CSV file and read its contents
    with open(csv_file, 'r') as file:
        reader = csv.reader(file)
        
        # Iterate through each row in the CSV file
        for i, row in enumerate(reader):
            # Skip the first row
            if i == 0:
                continue
            
            # Iterate through each specified column
            for j, col in enumerate(columns):
                # Append the value in the specified column to the corresponding list
                imported_columns[j].append(float(row[col]))
    
    # Convert the lists to NumPy arrays
    arrays = [np.array(col) for col in imported_columns]
    
    return arrays



rho_440='/media/favour/LaCie/small_molecules/rhodamine/out/rhodamine/build/flux/TRANS_TimeLine_s100.csv'
rho_393 = '/media/favour/LaCie/small_molecules/rhodamine/out/rho_393/complete/rho_393/flux/TRANS_TimeLine_s100.csv'
tar_440 = '/media/favour/LaCie/small_molecules/tariq/out/440/tariq/build/flux/TRANS_TimeLine_s100.csv'
tar_393 = '/media/favour/LaCie/small_molecules/tariq/out/393/out/trq_393/flux/TRANS_TimeLine_s100.csv'
ang = '/media/favour/LaCie/x32/angx32/out/angx32/flux/TRANS_TimeLine_s100.csv'
pen = '/media/favour/LaCie/x32/dense/flux/TRANS_TimeLine_s100.csv'
tat = '/media/favour/LaCie/x32/tatx32/out/1000ns/tatx32/flux/TRANS_TimeLine_s100.csv'
mer12 = '/media/favour/LaCie/x32/12mer12x32/complete/flux/TRANS_TimeLine_s100.csv'
mer13 = '/media/favour/LaCie/x32/12mer13x32/1000ns/12mer13x32/flux/TRANS_TimeLine_s100.csv'
DKP ='/media/favour/LaCie/x32/2merx32/out/2merx32/flux/TRANS_TimeLine_s100.csv'
PPF = '/media/favour/LaCie/x32/4merx32/out/4merx32/flux/TRANS_TimeLine_s100.csv'
#print(csv_file.columns)


columns_rho_440 = [1, 2,16]
arrays_rho_440 = import_columns_from_csv(rho_440, columns_rho_440)

columns_rho_393 = [1, 2,16]
arrays_rho_393 = import_columns_from_csv(rho_393, columns_rho_393)

columns_tar_393 = [1, 2,16]
arrays_tar_393 = import_columns_from_csv(tar_393, columns_tar_393)

columns_tar_440 = [1, 2,16]
arrays_tar_440 = import_columns_from_csv(tar_440, columns_tar_440)

columns_ang = [1, 2,16]
arrays_ang = import_columns_from_csv(ang, columns_ang)

columns_pen = [1, 2,16]
arrays_pen = import_columns_from_csv(pen, columns_pen)

columns_tat = [1, 2,16]
arrays_tat = import_columns_from_csv(tat, columns_tat)

columns_mer12 = [1, 2,16]
arrays_mer12 = import_columns_from_csv(mer12, columns_mer12)

columns_mer13 = [1, 2,16]
arrays_mer13 = import_columns_from_csv(mer13, columns_mer13)

columns_DKP = [1, 2,16]
arrays_DKP = import_columns_from_csv(DKP, columns_DKP)

columns_PPF = [1, 2,16]
arrays_PPF = import_columns_from_csv(PPF, columns_PPF)


#print(arrays_lf001[0])  # time(ns)
#print(arrays_lf001[1])  # dt(ns) need to do average of this over 100 to get 1 ns
#print(arrays_lf001[2])  # number of crossings (sum)

# %%
def import_columns_from_csv(csv_file, columns):
    # Initialize empty lists to store the columns
    imported_columns = [[] for _ in range(len(columns))]
    
    # Open the CSV file and read its contents
    with open(csv_file, 'r') as file:
        reader = csv.reader(file)
        
        # Iterate through each row in the CSV file
        for i, row in enumerate(reader):
            # Skip the first row
            if i == 0:
                continue
            
            # Iterate through each specified column
            for j, col in enumerate(columns):
                # Append the value in the specified column to the corresponding list
                imported_columns[j].append(float(row[col]))
    
    # Convert the lists to NumPy arrays
    arrays = [np.array(col) for col in imported_columns]
    
    return arrays



zota='/media/favour/LaCie/collab/zota/flux/TRANS_TimeLine_s100.csv'
cmld = '/media/favour/LaCie/collab/cmld/flux/TRANS_TimeLine_s100.csv'


zota_big='/media/favour/LaCie/collab_big/zota/flux/TRANS_TimeLine_s100.csv'
cmld_big = '/media/favour/LaCie/collab_big/cmld_2_big/flux/TRANS_TimeLine_s100.csv'


zota_2us='/media/favour/LaCie/collab_big/zota/zota_2us/flux/TRANS_TimeLine_s100.csv'
cmld_2us = '/media/favour/LaCie/collab_big/cmld_2_big/cmld_2us/flux/TRANS_TimeLine_s100.csv'


columns_zota = [1, 2,17]
arrays_zota = import_columns_from_csv(zota, columns_zota)

columns_cmld = [1, 2,17]
arrays_cmld = import_columns_from_csv(cmld, columns_cmld)

columns_zota_big = [1, 2,17]
arrays_zota_big = import_columns_from_csv(zota_big, columns_zota_big)

columns_cmld_big = [1, 2,17]
arrays_cmld_big = import_columns_from_csv(cmld_big, columns_cmld_big)


columns_zota_2us = [1, 2,17]
arrays_zota_2us = import_columns_from_csv(zota_2us, columns_zota_2us)

columns_cmld_2us = [1, 2,17]
arrays_cmld_2us = import_columns_from_csv(cmld_2us, columns_cmld_2us)

# %%
#cyt= '/Users/favour/Desktop/PhD/bigger-box/tabex/flux/TRANS_TimeLine_s100.csv'
#frame = pd.read_csv(cyt)
#frame.head()

# %%
rate_lf001= arrays_lf001[2]/arrays_lf001[0] #number of crossings/total time
time_lf001 =arrays_lf001[0]

rate_fas= arrays_fas[2]/arrays_fas[0] #number of crossings/total time
time_fas =arrays_fas[0]

rate_nh3= arrays_nh3[2]/arrays_nh3[0] #number of crossings/total time
time_nh3 =arrays_nh3[0]

rate_nic= arrays_nic[2]/arrays_nic[0] #number of crossings/total time
time_nic =arrays_nic[0]

rate_cyt= arrays_cyt[2]/arrays_cyt[0]#number of crossings/total time
time_cyt =arrays_cyt[0]

rate_fas_440= arrays_fas_440[2]/arrays_fas_440[0]#number of crossings/total time
time_fas_440 =arrays_fas_440[0]

rate_nic_440= arrays_nic_440[2]/arrays_nic_440[0]#number of crossings/total time
time_nic_440 =arrays_nic_440[0]

rate_nh3_440= arrays_nh3_440[2]/arrays_nh3_440[0]#number of crossings/total time
time_nh3_440 =arrays_nh3_440[0]

rate_nh3_310= arrays_nh3_310[2]/arrays_nh3_310[0]#number of crossings/total time
time_nh3_310 =arrays_nh3_310[0]

rate_nic_310= arrays_nic_310[2]/arrays_nic_310[0]#number of crossings/total time
time_nic_310 =arrays_nic_310[0]

# %%
rate_rho_440= arrays_rho_440[2]/arrays_rho_440[0] #number of crossings/total time
time_rho_440 =arrays_rho_440[0]

rate_rho_393= arrays_rho_393[2]/arrays_rho_393[0] #number of crossings/total time
time_rho_393 =arrays_rho_393[0]

rate_tar_393= arrays_tar_393[2]/arrays_tar_393[0] #number of crossings/total time
time_tar_393 =arrays_tar_393[0]

rate_tar_440= arrays_tar_440[2]/arrays_tar_440[0] #number of crossings/total time
time_tar_440 =arrays_tar_440[0]

rate_ang= arrays_ang[2]/arrays_ang[0] #number of crossings/total time
time_ang =arrays_ang[0]

rate_pen= arrays_pen[2]/arrays_pen[0] #number of crossings/total time
time_pen =arrays_pen[0]

rate_tat= arrays_tat[2]/arrays_tat[0] #number of crossings/total time
time_tat =arrays_tat[0]

rate_mer12= arrays_mer12[2]/arrays_mer12[0] #number of crossings/total time
time_mer12 =arrays_mer12[0]

rate_mer13= arrays_mer13[2]/arrays_mer13[0] #number of crossings/total time
time_mer13 =arrays_mer13[0]


rate_PPF= arrays_PPF[2]/arrays_PPF[0] #number of crossings/total time
time_PPF =arrays_PPF[0]

rate_DKP= arrays_DKP[2]/arrays_DKP[0] #number of crossings/total time
time_DKP =arrays_DKP[0]

# %%
#collab
rate_zota= arrays_zota[2]/arrays_zota[0] #number of crossings/total time
time_zota =arrays_zota[0]

rate_cmld= arrays_cmld[2]/arrays_cmld[0] #number of crossings/total time
time_cmld =arrays_cmld[0]


rate_zota_big= arrays_zota_big[2]/arrays_zota_big[0] #number of crossings/total time
time_zota_big =arrays_zota_big[0]

rate_cmld_big= arrays_cmld_big[2]/arrays_cmld_big[0] #number of crossings/total time
time_cmld_big =arrays_cmld_big[0]


rate_zota_2us= arrays_zota_2us[2]/arrays_zota_2us[0] #number of crossings/total time
time_zota_2us =arrays_zota_2us[0]

rate_cmld_2us= arrays_cmld_2us[2]/arrays_cmld_2us[0] #number of crossings/total time
time_cmld_2us =arrays_cmld_2us[0]

# %%
plt.plot(time_fas, rate_fas, label='Fasudil')
plt.plot(time_lf001, rate_lf001, label='LF001')
plt.plot(time_nh3, rate_nh3, label='Ammonia')
plt.plot(time_nic, rate_nic, label ='Nicotine')
#plt.plot(time_nic[9:], running_mean(rate_nic,10), label='Nicotine averaged')
plt.plot(time_cyt, rate_cyt, label='Cytisine')
plt.plot(time_fas_440, rate_fas_440, label='Fasudil at 440K')
plt.plot(time_nic_440, rate_nic_440, label='Nicotine at 440K')
plt.plot(time_nh3_440, rate_nh3_440, label='Ammonia at 440K')
plt.plot(time_nh3_310, rate_nh3_310, label='Ammonia at 310K')
plt.plot(time_nic_310, rate_nic_310, label='Nicotine at 310K')
plt.xlabel('Time(ns)')
plt.ylabel(r'Rate(ns$^{-1}$)')
plt.title('Rate crossings against time')
#plt.legend()
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.savefig('steady_state.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.plot(time_rho_440, rate_rho_440, label='Rhodamine at 440K')
plt.plot(time_rho_393, rate_rho_393, label='Rhodamine at 393K')
plt.plot(time_tar_393, rate_tar_393, label='Tariquidar at 393K')
plt.plot(time_tar_440, rate_tar_440, label='Tariquidar at 440K')
plt.plot(time_ang, rate_ang, label='Angiopep at 440K')
plt.plot(time_tat, rate_tat, label='TAT at 440K')
plt.plot(time_mer12, rate_mer12, label='12mer1.2 at 440K')
plt.plot(time_mer13, rate_mer13, label='12mer1.3 at 440K')
plt.plot(time_PPF, rate_PPF, label='PPF at 440K')
plt.plot(time_DKP, rate_DKP, label='DKP at 440K')

plt.xlabel('Time(ns)')
plt.ylabel(r'Rate(ns$^{-1}$)')
plt.title('Rate crossings against time')
#plt.legend()
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.savefig('steady_state_new.png', dpi=300,bbox_inches='tight')
plt.show()

# %%
plt.plot(time_tar_440, rate_tar_440,color ='olive',linewidth= 5 ,label='TAR')
plt.plot(time_rho_440, rate_rho_440,color='m',linestyle='--',linewidth= 5,label='rho')


plt.xlabel('Time(ns)')
plt.ylabel(r'Rate(ns$^{-1}$)')
plt.title('Rate crossings against time')
plt.xlim(0,1000)
#plt.ylim(0,0.6)
#plt.legend()
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
#plt.savefig('steady_state_peps.png', dpi=300,bbox_inches='tight')
plt.show()

# %%
plt.plot(time_ang, rate_ang,color ='olive',linewidth= 5 ,label='Angiopep')
plt.plot(time_tat, rate_tat,color='m',linestyle='--',linewidth= 5,label='TAT')
plt.plot(time_pen, rate_pen,color='dodgerblue',linestyle=':',linewidth= 5, label='Penetratin')


plt.xlabel('Time(ns)')
plt.ylabel(r'Rate(ns$^{-1}$)')
plt.title('Rate crossings against time')
plt.xlim(0,1000)
#plt.ylim(0,0.6)
#plt.legend()
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
#plt.savefig('steady_state_peps.png', dpi=300,bbox_inches='tight')
plt.show()

# %%
plt.plot(time_zota, rate_zota,color ='olive',linewidth= 5 ,label='Zota')
plt.plot(time_cmld, rate_cmld,color='m',linestyle='--',linewidth= 5,label='CMLD')


plt.xlabel('Time(ns)')
plt.ylabel(r'Rate(ns$^{-1}$)')
plt.title('Rate crossings against time')
plt.xlim(0,1000)
#plt.ylim(0,0.6)
#plt.legend()
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.savefig('steady_state_collab.png', dpi=300,bbox_inches='tight')
plt.show()

# %%
plt.plot(time_zota_big, rate_zota_big,color ='olive',linewidth= 5 ,label='Zota')
plt.plot(time_cmld_big, rate_cmld_big,color='m',linestyle='--',linewidth= 5,label='CMLD')


plt.xlabel('Time(ns)')
plt.ylabel(r'Rate(ns$^{-1}$)')
plt.title('Rate crossings against time')
plt.xlim(0,1000)
#plt.ylim(0,0.6)
#plt.legend()
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.savefig('steady_state_collab_big.png', dpi=300,bbox_inches='tight')
plt.show()

# %%
plt.plot(time_zota_2us, rate_zota_2us,color ='olive',linewidth= 5 ,label='Zota')
plt.plot(time_cmld_2us, rate_cmld_2us,color='m',linestyle='--',linewidth= 5,label='CMLD')


plt.xlabel('Time(ns)')
plt.ylabel(r'Rate(ns$^{-1}$)')
plt.title('Rate crossings against time')
plt.xlim(0,2000)
#plt.ylim(0,0.6)
#plt.legend()
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.savefig('steady_state_collab_2us.png', dpi=300,bbox_inches='tight')
plt.show()

# %%
from tqdm import tqdm

# %%
plt.plot(time_DKP, rate_DKP,linewidth= 3, label='DKP')
plt.plot(time_PPF, rate_PPF,linewidth= 3, label='PPF')



plt.xlabel('Time(ns)')
plt.ylabel(r'Rate(ns$^{-1}$)')
plt.title('Rate crossings against time')
#plt.legend()
plt.xlim(0,1000)
plt.ylim(0,0.6)
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.savefig('steady_state_tiny_pep.png', dpi=300,bbox_inches='tight')
plt.show()

# %%
plt.plot(time_fas_440, rate_fas_440, label='Fasudil',linewidth= 3, color = 'red')
plt.plot(time_nic_440, rate_nic_440, label='Nicotine', linewidth= 3,color= 'orange')
plt.plot(time_nh3_440, rate_nh3_440, label='Ammonia',linewidth= 3, color='green')

plt.xlabel('Time(ns)')
plt.ylabel(r'Rate(ns$^{-1}$)')
plt.title('Rate crossings against time')
#plt.legend()
plt.xlim(0,1000)
plt.ylim(0,0.6)
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.savefig('steady_state_cont.png', dpi=300, bbox_inches='tight')
plt.show()
